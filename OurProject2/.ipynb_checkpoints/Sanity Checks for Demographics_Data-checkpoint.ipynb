# %% [markdown]
# Sanity Checking Demographics Data
# Notes: from the data dictionaries
#
# * Age in years of the participant at the time of screening. Individuals 80 and over are topcoded at 80 years of age.
# * Gender could have a missing value: 1 = Male, 2 = Female, 0 = unknown, * = missing

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
demographics_data = pd.read_csv('./Demographics_2013_2014.csv')

# %%
demographics_data.columns
# Out:
# Index(['SEQN', 'SDDSRVYR', 'RIDSTATR', 'RIAGENDR', 'RIDAGEYR', 'RIDAGEMN',
#        'RIDRETH1', 'RIDRETH3', 'RIDEXMON', 'RIDEXAGM', 'DMQMILIZ', 'DMQADFC',
#        'DMDBORN4', 'DMDCITZN', 'DMDYRSUS', 'DMDEDUC3', 'DMDEDUC2', 'DMDMARTL',
#        'RIDEXPRG', 'SIALANG', 'SIAPROXY', 'SIAINTRP', 'FIALANG', 'FIAPROXY',
#        'FIAINTRP', 'MIALANG', 'MIAPROXY', 'MIAINTRP', 'AIALANGA', 'DMDHHSIZ',
#        'DMDFMSIZ', 'DMDHHSZA', 'DMDHHSZB', 'DMDHHSZE', 'DMDHRGND', 'DMDHRAGE',
#        'DMDHRBR4', 'DMDHREDU', 'DMDHRMAR', 'DMDHSEDU', 'WTINT2YR', 'WTMEC2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDHHIN2', 'INDFMIN2', 'INDFMPIR'],
#       dtype='object')

# %%
demographics_data.RIAGENDR.value_counts()
# Out:
# 2.000000e+00    5172
# 1.000000e+00    5003
# 3.687825e-40      25
# Name: RIAGENDR, dtype: int64

# %%
demographics_data.hist("RIAGENDR")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x112e38b38>]], dtype=object)

# %%
demographics_data.RIDAGEYR[demographics_data.RIAGENDR != 1][demographics_data.RIAGENDR != 2].value_counts()
# Out:
# 3.687825e-40    25
# Name: RIDAGEYR, dtype: int64

# %%
demographics_data[(demographics_data.RIAGENDR == 1) | (demographics_data.RIAGENDR == 2)]
# Out:
#           SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0      73557.0       8.0       2.0       1.0      69.0         0         4
# 1      73558.0       8.0       2.0       1.0      54.0         0         3
# 2      73559.0       8.0       2.0       1.0      72.0         0         3
# 3      73560.0       8.0       2.0       1.0       9.0         0         3
# 4      73561.0       8.0       2.0       2.0      73.0         0         3
# 5      73562.0       8.0       2.0       1.0      56.0         0         1
# 6      73563.0       8.0       2.0       1.0       0.0         5         3
# 7      73564.0       8.0       2.0       2.0      61.0         0         3
# 8      73565.0       8.0       1.0       1.0      42.0         0         2
# 9      73566.0       8.0       2.0       2.0      56.0         0         3
# 10     73567.0       8.0       2.0       1.0      65.0         0         3
# ...

# %%
demographics_data.RIDAGEYR.describe()
# Out:
# count    10200.000000
# mean        31.406961
# std         24.441336
# min          0.000000
# 25%          9.000000
# 50%         26.000000
# 75%         52.000000
# max         80.000000
# Name: RIDAGEYR, dtype: float64

# %%
demographics_data.hist("RIDAGEYR", bins = 80)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x113372390>]], dtype=object)

# %%
demographics_data.RIDAGEYR[demographics_data.RIDAGEYR < 1].value_counts()
# Out:
# 0.000000e+00    405
# 3.687825e-40     25
# Name: RIDAGEYR, dtype: int64

# %%
demographics_data.RIDAGEYR[demographics_data.RIDAGEYR < 16].value_counts()
# Out:
# 0.000000e+00    405
# 2.000000e+00    278
# 1.000000e+00    262
# 6.000000e+00    262
# 7.000000e+00    233
# 4.000000e+00    230
# 1.100000e+01    223
# 1.000000e+01    223
# 3.000000e+00    220
# 8.000000e+00    217
# 9.000000e+00    213
# 5.000000e+00    208
# 1.400000e+01    203
# 1.200000e+01    193
# 1.500000e+01    176
# 1.300000e+01    165
# 3.687825e-40     25
# Name: RIDAGEYR, dtype: int64
