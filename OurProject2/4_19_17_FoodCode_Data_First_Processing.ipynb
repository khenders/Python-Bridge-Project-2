# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
foodcode_data = pd.read_csv('./Foodcode_2013_2014.csv')

# %%
foodcode_data.columns
# Out:
# Index(['DRXFDCD', 'DRXFCSD', 'DRXFCLD'], dtype='object')

# %%
foodcode_data.DRXFDCD.count()
# Out:
# 8600

# %%
dairy_data = foodcode_data.DRXFDCD.between(10000000, 19999999, inclusive = True)
dairy_data.head()
# this doesn't work, not pulling back the correct data
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: DRXFDCD, dtype: bool

# %%
dairy_data = foodcode_data.DRXFDCD[foodcode_data.DRXFDCD.between(10000000, 19999999, inclusive = True)].astype(int)
dairy_data.head() 
# this pulls back the correct values
# Out:
# 0    11000000
# 1    11100000
# 2    11111000
# 3    11111100
# 4    11111150
# Name: DRXFDCD, dtype: int64

# %%
dairy_data = foodcode_data.DRXFDCD[foodcode_data.DRXFDCD.between(10000000, 19999999, inclusive = True)]
dairy_data.count() 
# this count is correct
# Out:
# 739

# %%
# doesn't work
dairy_data = foodcode_data.DRXFDCD[foodcode_data.DRXFDCD.between(10000000, 19999999, inclusive = True) & foodcode_data.DRXFDCD != (11710000, 11740551, inclusive = True)]
# Out:
#   File "<ipython-input-16-0e21e6e07523>", line 2
#     dairy_data = foodcode_data.DRXFDCD[foodcode_data.DRXFDCD.between(10000000, 19999999, inclusive = True) & foodcode_data.DRXFDCD != (11710000, 11740551, inclusive = True)]
#                                                                                                                                                                      ^
# SyntaxError: invalid syntax

# %%
def dairy_filter(item_code):
    result = False
    if ((10000000 <= item_code) and (item_code <= 19999999)) and (item_code not in range(11710000, 11740551)) :
        result = True
    return result

index_of_values_we_want = foodcode_data.DRXFDCD.apply(dairy_filter)
dairy_data = foodcode_data[index_of_values_we_want]

# print(len(dairy_data))
dairy_data.head()
# dairy_data.count()
# dairy_data.columns()
# Out:
#       DRXFDCD                         DRXFCSD                         DRXFCLD
# 0  11000000.0                     MILK, HUMAN                     Milk, human
# 1  11100000.0                       MILK, NFS                       Milk, NFS
# 2  11111000.0                     MILK, WHOLE                     Milk, whole
# 3  11111100.0         MILK, LOW SODIUM, WHOLE         Milk, low sodium, whole
# 4  11111150.0  MILK, CALCIUM FORTIFIED, WHOLE  Milk, calcium fortified, whole

# %%
beef_data = foodcode_data.DRXFDCD[foodcode_data.DRXFDCD.between(21000100, 21701020, inclusive = True)].astype(int)
# print(len(beef_data))
beef_data.head() 
# this is correct
# Out:
# 743    21000100
# 744    21000110
# 745    21000120
# 746    21001000
# 747    21001010
# Name: DRXFDCD, dtype: int64

# %%
beef_data = foodcode_data.DRXFDCD[foodcode_data.DRXFDCD.between(21000100, 21701020, inclusive = True)]
beef_data.count()
# this is correct
# Out:
# 72

# %%
chicken_data = foodcode_data.DRXFDCD[foodcode_data.DRXFDCD.between(24100000, 24198840, inclusive = True)].astype(int)
chicken_data.head() 
# this is correct
# Out:
# 1010    24100000
# 1011    24100010
# 1012    24100020
# 1013    24102000
# 1014    24102010
# Name: DRXFDCD, dtype: int64

# %%
chicken_data.count()
# Out:
# 272

# %%
asparagus_data = foodcode_data.DRXFDCD[foodcode_data.DRXFDCD.between(75202000, 75202036, inclusive = True)].astype(int)
# asparagus_data.head() 
asparagus_data.count()
# this is correct
# Out:
# 24

# %%
dfa = asparagus_data.to_frame()
dfa
# Out:
#        DRXFDCD
# 6637  75202000
# 6638  75202001
# 6639  75202002
# 6640  75202003
# 6641  75202010
# 6642  75202011
# 6643  75202012
# 6644  75202013
# 6645  75202020
# 6646  75202021
# 6647  75202022
# 6648  75202023
# 6649  75202024
# 6650  75202025
# 6651  75202026
# 6652  75202027
# 6653  75202028
# 6654  75202029
# 6655  75202031
# 6656  75202032
# 6657  75202033
# 6658  75202034
# 6659  75202035
# 6660  75202036

# %%
dfa.columns = ['Foodcode']
list(dfa.columns)
# Out:
# ['Foodcode']

# %%
dfc = chicken_data.to_frame()
dfc
# Out:
#        DRXFDCD
# 1010  24100000
